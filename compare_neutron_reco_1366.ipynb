# %%
import numpy as np
import tifffile
import glob
import os

from reco_helper import get_spectrum

from matplotlib import pyplot as plt
# %matplotlib inline

from tqdm.auto import tqdm

# %%
before = tifffile.imread('/mnt/HD-LSDF/sd18a004/for_yaroslav/reconstructions_1366/127.tif')
after = tifffile.imread('/mnt/HD-LSDF/sd18a004/for_yaroslav/reconstructions_1366_processed/127.tif')

# %%
before.shape, after.shape
# Out:
# ((1366, 484, 484), (1364, 484, 484))

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 10))
ax1.imshow(before[:, 200])
ax2.imshow(after[:, 200])
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 10))
ax1.imshow(before[500])
ax2.imshow(after[500])
plt.show()

# %%
after = np.concatenate([after[[0]], after, after[[-1]]])

# %%
get_spectrum(before, after, binning=[4, 2, 2, 1])
