# %%
import tifffile
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
a = tifffile.imread('wasp_tv.tif')
b = tifffile.imread('wasp_no_tv.tif')

# %%
plt.figure(figsize=(16, 10))
plt.imshow(a, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.imshow(b, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.imshow(b-a)

# %%
c = tifffile.memmap('/mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/scan_0106/pr-pag/img-new-corr.tif')

# %%
c = tifffile.memmap('')

# %%
d = tifffile.memmap('/mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/scan_0106/pr-pag/pr-pag.tif')

# %%
plt.figure(figsize=(16, 10))
plt.imshow(c[0] - d[0])

# %%
orig_pr = tifffile.memmap('/mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/pr-pag-all-denoised/scan_0049-pr-pag-2p0.tif')

# %%
den = tifffile.memmap('/mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/scan_0049/ffcorr_corr_dead_px/denoised_scan_0049.tif')

# %%
plt.imshow(orig_pr[0] - b)

# %%
from src.datasets import get_paganin_converter

# %%
pogo = get_paganin_converter(b.shape[1], b.shape[0])

# %%
den_pr = pogo(den[0])

# %%
plt.figure(figsize=(16, 10))
plt.imshow(den_pr - b)

# %%
plt.imshow()

# %%
plt.plot(a[500])
plt.plot(b[500])
