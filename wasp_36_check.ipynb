# %%
import tifffile

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os
base_folder = '/mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/'

# %%
after = tifffile.imread('/mnt/data/denoising/wasp/36/scan_0106.tif')

# %%
before = tifffile.imread('/mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/scan_0106/ffcorr_corr_dead_px/scan_0106.tif')

# %%
before.shape
# Out:
# (7142, 516, 787)

# %%
i = 5581

# %%
plt.figure(figsize=(16, 10))
plt.imshow(after[i])

# %%
plt.figure(figsize=(16, 10))
plt.imshow(before[i+1])

# %%
plt.figure(figsize=(16, 10))
plt.imshow(after_dc[i])

# %%
plt.figure(figsize=(16, 10))
plt.imshow(before[i+1][100:300, 250:300])

# %%
from skimage.filters import gaussian

# %%
plt.figure(figsize=(16, 10))
plt.imshow(gaussian(before[i+1], sigma=1)[100:300, 250:300])

# %%
plt.figure(figsize=(16, 10))
plt.imshow(after[i][100:300, 250:300])

# %%
after_dc = tifffile.imread('/mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/scan_0106/ffcorr_corr_dead_px/denoised_dc_scan_0106.tif')

# %%
plt.figure(figsize=(16, 10))
plt.imshow(before[i:i+2].mean(0))

# %%
# !cp /mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/scan_0106/denoising-comparison/pr-pag-8bit.avi .
# !cp /mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/001/scan_0106/denoising-comparison/pr-pag-denoised-8bit.avi .

# %%
ls /mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/036/scan_*/pr-pag/pr-pag-2p0.tif
# Out:
# /mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/036/scan_0001/pr-pag/pr-pag-2p0.tif*
# /mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/036/scan_0002/pr-pag/pr-pag-2p0.tif*
# /mnt/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/036/scan_0003/pr-pag/pr-pag-2p0.tif*

# %%
a = tifffile.imread(os.path.join(base_folder, '001/pr-pag-all/scan_0106-pr-pag-2p0.tif'))

# %%
a = tifffile.imread(os.path.join(base_folder, '001/scan_0106/pr-pag/img-corr-bad-px-reg2p0.tif'))

# %%
b = tifffile.imread(os.path.join(base_folder, '041/scan_0001/pr-pag/pr-pag-2p0.tif'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 b = tifffile.imread(os.path.join(base_folder, '041/scan_0001/pr-pag/img-no-corr-bad-px.tif'))
#
# File ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py:816, in imread(files, aszarr, **kwargs)
#     813     files = files[0]
#     815 if isinstance(files, (str, os.PathLike)) or hasattr(files, 'seek'):
# --> 816     with TiffFile(files, **kwargs_file) as tif:
#     817         if aszarr:
#     818             return tif.aszarr(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py:3000, in TiffFile.__init__(self, arg, mode, name, offset, size, _multifile, _useframes, _master, **kwargs)
#    2997 if mode not in (None, 'rb', 'r+b'):
#    2998     raise ValueError(f'invalid mode {mode!r}')
# -> 3000 fh = FileHandle(arg, mode=mode, name=name, offset=offset, size=size)
#    3001 self._fh = fh
#    3002 self._multifile = bool(_multifile)
#
# File ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py:9537, in FileHandle.__init__(self, file, mode, name, offset, size)
#    9535 self.is_file = None
#    9536 self._lock = NullContext()
# -> 9537 self.open()
#
# File ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py:9550, in FileHandle.open(self)
#    9548 self._file = os.path.realpath(self._file)
#    9549 self._dir, self._name = os.path.split(self._file)
# -> 9550 self._fh = open(self._file, self._mode)
#    9551 self._close = True
#    9552 if self._offset is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/autofs/LSDF/projects/code-vita/BM_beamtimes/2022_02_P23/27-02/trichogramma/041/scan_0001/pr-pag/img-no-corr-bad-px.tif'

# %%
a.shape, before.shape
# Out:
# ((8997, 516, 787), (7142, 516, 787))

# %%
plt.figure(figsize=(16, 10))
plt.imshow(a[0])
