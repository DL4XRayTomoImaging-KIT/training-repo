# %%
import numpy as np
import tifffile
import glob
import os

from reco_helper import get_spectrum

from matplotlib import pyplot as plt
# %matplotlib inline

from tqdm.auto import tqdm

# %%
before = tifffile.imread('/mnt/HD-LSDF/sd18a004/for_yaroslav/reconstructions_2840/127.tif')
after = tifffile.imread('/mnt/HD-LSDF/sd18a004/for_yaroslav/reconstructions_2840_processed/127.tif')

# %%
before.shape, after.shape
# Out:
# ((2840, 484, 484), (2838, 484, 484))

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 10))
ax1.imshow(before[:, 200])
ax2.imshow(after[:, 200])
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 10))
ax1.imshow(before[1000])
ax2.imshow(after[1000])
plt.show()

# %%
after = np.concatenate([after[[0]], after, after[[-1]]])

# %%
get_spectrum(before, after, binning=[1, 1, 1, 1])
